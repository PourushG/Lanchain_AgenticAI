# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(model="embeddinggemma")
embeddings
# Out:
# OllamaEmbeddings(model='embeddinggemma', validate_model_on_init=False, base_url=None, client_kwargs={}, async_client_kwargs={}, sync_client_kwargs={}, mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, keep_alive=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None)

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt", encoding="utf-8")

docs = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 50)
chunks = splitter.split_documents(docs)
chunks
# Out:
# [Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='1. Company Overview\n\nDatopic Technologies Private Limited is an India-based emerging technology and innovation-driven IT services company, incorporated on 7 February 2017 under the Companies Act, 2013. Its Corporate Identification Number (CIN) is U74999DL2017PTC312445, and it is registered with the Registrar of Companies, Delhi.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='The company’s registered office is located at RZ-77A, Dabri Extension, Main Palam Road, New Delhi – 110045, India. Operationally, Datopic has also established a significant presence in Noida, Uttar Pradesh, serving as its primary technology and development hub.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Datopic Technologies is guided by the vision of “transforming data into intelligence and innovation into action.” Its central focus lies in building next-generation digital solutions for enterprises, leveraging cutting-edge technologies such as Artificial Intelligence (AI), Blockchain, Cloud Computing, Cybersecurity, and Data Analytics.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='With a lean yet talented workforce (estimated 20–50 professionals), Datopic has rapidly built credibility through specialized digital transformation projects, catering to both domestic and international clients. The company aims to empower organizations to reimagine their operations, enhance decision-making, and achieve sustainable digital growth through the intelligent application of emerging technologies.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Key leadership includes Mr. Saurabh Jain and Mr. Sumit Chauhan, both experienced technology professionals with deep expertise in enterprise systems, digital solutions, and IT consulting.\n\n2. Mission, Vision, and Core Values\n\nMission:\nTo deliver intelligent and secure digital transformation solutions that empower enterprises to maximize efficiency, agility, and innovation using data-driven intelligence and advanced technologies.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Vision:\nTo emerge as a global technology partner of choice by continuously innovating, adapting, and integrating futuristic solutions that bridge the gap between technology and business outcomes.\n\nCore Values:\n\nInnovation First: Constantly evolving to integrate emerging technologies into real-world business problems.\n\nIntegrity: Building trustworthy digital ecosystems with transparency and accountability.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Client Centricity: Focusing on measurable business impact and long-term value for clients.\n\nCollaboration: Promoting teamwork across multi-disciplinary functions and partner ecosystems.\n\nExcellence: Commitment to quality, scalability, and performance across all engagements.\n\n3. Services & Technology Portfolio\n\nDatopic’s expertise covers a broad spectrum of digital transformation services, strategically grouped under five main service lines:\n\na) Product Engineering and Software Development'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='a) Product Engineering and Software Development\n\nDatopic specializes in end-to-end product lifecycle management, helping clients conceptualize, design, develop, test, and deploy software applications and digital platforms. The company focuses on agile and DevOps methodologies to ensure rapid delivery with high scalability and maintainability.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Technologies used include Python, Java, Node.js, React, TensorFlow, AWS, and Azure, among others. Solutions range from enterprise web applications to AI-integrated products and IoT dashboards.\n\nb) Artificial Intelligence and Data Analytics'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='b) Artificial Intelligence and Data Analytics\n\nDatopic’s data division focuses on predictive analytics, natural language processing (NLP), and computer vision. It helps organizations harness raw data to gain actionable insights through machine learning models, data visualization, and intelligent automation.\n\nTypical use cases include:\n\nPredictive maintenance for manufacturing.\n\nFraud detection and anomaly identification for financial systems.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='AI chatbots and recommendation systems for customer engagement.\n\nc) Cybersecurity and Infrastructure Management\n\nIn today’s data-driven economy, Datopic offers robust cybersecurity and network protection solutions, including penetration testing, risk assessment, endpoint security, and identity management.\n\nIts cybersecurity frameworks follow NIST and ISO 27001 standards, providing clients with compliance-ready and secure IT infrastructure.\n\nd) Blockchain and Digital Transformation'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='d) Blockchain and Digital Transformation\n\nDatopic has been an early adopter of blockchain, working on supply chain transparency, digital identity, and smart contract implementation. The company provides blockchain consulting, DApp development, and system integration with traditional architectures to create trustless, decentralized ecosystems.\n\ne) Strategic Consulting and IT Modernization'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='e) Strategic Consulting and IT Modernization\n\nThe company provides strategic guidance to organizations aiming to modernize legacy systems. Their consultants assess current workflows, recommend cloud migration strategies, and design digital roadmaps aligned with business goals.\n\n4. Industry Focus and Market Positioning\n\nDatopic Technologies operates in the intersection of technology, consulting, and innovation. Its primary target industries include:'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Finance and Fintech: AI-based fraud detection and blockchain-backed transactions.\n\nHealthcare: Secure patient data management, predictive analytics for diagnosis, and AI-driven image processing.\n\nGovernment & Public Sector: Cybersecurity and data transparency projects.\n\nRetail & E-Commerce: Data-driven customer analytics and automation systems.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='The company’s market positioning is that of a specialized, high-value boutique technology firm—competing through innovation, agility, and custom-tailored solutions rather than large-scale outsourcing.\n\nBy combining the precision of a consulting firm with the agility of a tech startup, Datopic has been able to differentiate itself in an overcrowded IT service market.\n\n5. Corporate Structure and Financial Overview\n\nType: Private Limited Company\n\nCIN: U74999DL2017PTC312445'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='CIN: U74999DL2017PTC312445\n\nAuthorized Capital: ₹1,00,000\n\nPaid-up Capital: ₹1,00,000\n\nStatus: Active (as per Ministry of Corporate Affairs filings)\n\nRegistered Office: New Delhi, India\n\nOperational Hub: Sector 65, Noida'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Operational Hub: Sector 65, Noida\n\nWhile detailed financial statements are not publicly available, the company operates as a privately held entity with ongoing business engagements in India, the Middle East, and select Western markets. Its lean cost structure and specialized consulting model suggest a focus on profitability through intellectual capital rather than large infrastructure costs.\n\n6. Growth, Partnerships, and Key Milestones'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='6. Growth, Partnerships, and Key Milestones\n\n2017: Officially incorporated and began operations in digital product development.\n\n2018–2019: Expanded into data analytics and automation consulting for small and medium enterprises (SMEs).\n\n2020–2021: Introduced dedicated AI & ML services division during the pandemic, focusing on remote analytics and process automation.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='2022: Established partnerships with emerging tech startups and participated in campus recruitment drives to expand talent acquisition.\n\n2023–2024: Initiated multiple enterprise-level collaborations in blockchain and digital infrastructure modernization projects across finance and logistics sectors.\n\nThese progressive steps reflect Datopic’s commitment to evolving with technological trends and maintaining an innovation-first growth model.\n\n7. Work Culture and Employee Perspective'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='7. Work Culture and Employee Perspective\n\nBased on employee reviews (Glassdoor, AmbitionBox), Datopic Technologies is recognized for maintaining an open, learning-oriented work culture. The company encourages innovation, provides mentorship for young engineers, and maintains flat organizational hierarchies for transparent communication.\n\nWorkplace highlights include:\n\nMentorship programs for AI/ML developers.\n\nFlexible work arrangements and project-based autonomy.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Opportunities to work on real-world enterprise challenges early in one’s career.\n\nThis has resulted in 93% employee recommendation ratings and high retention within the core development team.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='8. Strengths, Weaknesses, Opportunities, and Threats (SWOT Analysis)\nStrengths\tWeaknesses\nStrong focus on next-gen tech (AI, Blockchain, Cybersecurity)\tLimited global brand visibility\nAgile delivery and innovation-first mindset\tSmaller team size restricts project scale\nLeadership with deep technical expertise\tLimited public financial disclosures\nPositive internal culture promoting R&D\tReliance on niche market contracts\nOpportunities\tThreats'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Opportunities\tThreats\nGlobal demand for AI-driven digital transformation\tRapid tech changes may outpace current capabilities\nExpansion into sectors like HealthTech and FinTech\tCompetition from larger IT giants (TCS, Infosys, Accenture)\nDevelopment of proprietary SaaS platforms\tCybersecurity threats and regulatory challenges\nStrategic partnerships with academic and research bodies\tMarket volatility impacting SME IT budgets\n9. Future Outlook and Strategic Roadmap'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Datopic Technologies envisions scaling its AI and data-driven consulting capabilities to enterprise-grade clients by 2026, with plans to:\n\nLaunch a proprietary AI-powered analytics platform tailored for cybersecurity and compliance management.\n\nEstablish global delivery partnerships in the Middle East and North America.\n\nExpand hiring and internship programs for ML, cloud, and full-stack engineering domains.\n\nInvest in R&D labs for AI, edge computing, and blockchain-based identity systems.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Their forward-looking strategy revolves around sustainable innovation, talent-driven execution, and digital trust frameworks—positioning Datopic among India’s next-generation technology leaders.\n\n10. Conclusion'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='10. Conclusion\n\nDatopic Technologies Pvt. Ltd. represents a promising new-age digital solutions company focused on innovation, data intelligence, and secure transformation. Through a combination of technical depth, client-first philosophy, and adaptability, it continues to grow as a trusted partner for businesses navigating the evolving digital landscape.'),
#  Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='In an era where AI, data, and cybersecurity define competitive advantage, Datopic’s vision to “connect data with decisions” aligns perfectly with the future of enterprise technology.')]

# %%
chunks_embeddings = embeddings.embed_documents([doc.page_content for doc in docs])
chunks_embeddings

# %%
len(chunks_embeddings[0])
# Out:
# 768
