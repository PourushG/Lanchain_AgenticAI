# %% [markdown]
# ### Vector Stores & REtrievers
#
# Langchain's vector and retriever abstractions are designed to support retrieval of data -- from (vector) databases and other sources-- for integration with LLM workflows. They are important for applications that fetch data to be reasoned over as part of model inference, as in the case of retrieval-augmented generation

# %% [markdown]
# ### Documents
#
# Langchain implements a Document abstraction, whihc is intended to represent a unit of text and associated metadata. It has two attributes:
#
# page_content: a string representing the content
#
# metadata: a dict containing arbitrary metadata. The metadata attribute can capture information about hte source of the document, its relationship to other documents, and otehr information. Note that an individual document object often represents a chunk of a larger document.

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain_chroma import Chroma
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
load_dotenv()

groq_api_key = os.getenv("GROQ_API")
os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

llm = ChatGroq(model="openai/gpt-oss-120b", groq_api_key=groq_api_key)

# %%
# data loading
from langchain_community.document_loaders import TextLoader
loader = TextLoader('C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt', encoding='utf-8')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='1. Company Overview\n\nDatopic Technologies Private Limited is an India-based emerging technology and innovation-driven IT services company, incorporated on 7 February 2017 under the Companies Act, 2013. Its Corporate Identification Number (CIN) is U74999DL2017PTC312445, and it is registered with the Registrar of Companies, Delhi.\n\nThe company’s registered office is located at RZ-77A, Dabri Extension, Main Palam Road, New Delhi – 110045, India. Operationally, Datopic has also established a significant presence in Noida, Uttar Pradesh, serving as its primary technology and development hub.\n\nDatopic Technologies is guided by the vision of “transforming data into intelligence and innovation into action.” Its central focus lies in building next-generation digital solutions for enterprises, leveraging cutting-edge technologies such as Artificial Intelligence (AI), Blockchain, Cloud Computing, Cybersecurity, and Data Analytics.\n\nWith a lean yet talented workforce (estimated 20–50 professionals), Datopic has rapidly built credibility through specialized digital transformation projects, catering to both domestic and international clients. The company aims to empower organizations to reimagine their operations, enhance decision-making, and achieve sustainable digital growth through the intelligent application of emerging technologies.\n\nKey leadership includes Mr. Saurabh Jain and Mr. Sumit Chauhan, both experienced technology professionals with deep expertise in enterprise systems, digital solutions, and IT consulting.\n\n2. Mission, Vision, and Core Values\n\nMission:\nTo deliver intelligent and secure digital transformation solutions that empower enterprises to maximize efficiency, agility, and innovation using data-driven intelligence and advanced technologies.\n\nVision:\nTo emerge as a global technology partner of choice by continuously innovating, adapting, and integrating futuristic solutions that bridge the gap between technology and business outcomes.\n\nCore Values:\n\nInnovation First: Constantly evolving to integrate emerging technologies into real-world business problems.\n\nIntegrity: Building trustworthy digital ecosystems with transparency and accountability.\n\nClient Centricity: Focusing on measurable business impact and long-term value for clients.\n\nCollaboration: Promoting teamwork across multi-disciplinary functions and partner ecosystems.\n\nExcellence: Commitment to quality, scalability, and performance across all engagements.\n\n3. Services & Technology Portfolio\n\nDatopic’s expertise covers a broad spectrum of digital transformation services, strategically grouped under five main service lines:\n\na) Product Engineering and Software Development\n\nDatopic specializes in end-to-end product lifecycle management, helping clients conceptualize, design, develop, test, and deploy software applications and digital platforms. The company focuses on agile and DevOps methodologies to ensure rapid delivery with high scalability and maintainability.\n\nTechnologies used include Python, Java, Node.js, React, TensorFlow, AWS, and Azure, among others. Solutions range from enterprise web applications to AI-integrated products and IoT dashboards.\n\nb) Artificial Intelligence and Data Analytics\n\nDatopic’s data division focuses on predictive analytics, natural language processing (NLP), and computer vision. It helps organizations harness raw data to gain actionable insights through machine learning models, data visualization, and intelligent automation.\n\nTypical use cases include:\n\nPredictive maintenance for manufacturing.\n\nFraud detection and anomaly identification for financial systems.\n\nAI chatbots and recommendation systems for customer engagement.\n\nc) Cybersecurity and Infrastructure Management\n\nIn today’s data-driven economy, Datopic offers robust cybersecurity and network protec ...

# %%
# data chunking

from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size = 2000, chunk_overlap = 100)

chunks = splitter.split_documents(docs)
print(chunks)
# Out:
# [Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='1. Company Overview\n\nDatopic Technologies Private Limited is an India-based emerging technology and innovation-driven IT services company, incorporated on 7 February 2017 under the Companies Act, 2013. Its Corporate Identification Number (CIN) is U74999DL2017PTC312445, and it is registered with the Registrar of Companies, Delhi.\n\nThe company’s registered office is located at RZ-77A, Dabri Extension, Main Palam Road, New Delhi – 110045, India. Operationally, Datopic has also established a significant presence in Noida, Uttar Pradesh, serving as its primary technology and development hub.\n\nDatopic Technologies is guided by the vision of “transforming data into intelligence and innovation into action.” Its central focus lies in building next-generation digital solutions for enterprises, leveraging cutting-edge technologies such as Artificial Intelligence (AI), Blockchain, Cloud Computing, Cybersecurity, and Data Analytics.\n\nWith a lean yet talented workforce (estimated 20–50 professionals), Datopic has rapidly built credibility through specialized digital transformation projects, catering to both domestic and international clients. The company aims to empower organizations to reimagine their operations, enhance decision-making, and achieve sustainable digital growth through the intelligent application of emerging technologies.\n\nKey leadership includes Mr. Saurabh Jain and Mr. Sumit Chauhan, both experienced technology professionals with deep expertise in enterprise systems, digital solutions, and IT consulting.\n\n2. Mission, Vision, and Core Values\n\nMission:\nTo deliver intelligent and secure digital transformation solutions that empower enterprises to maximize efficiency, agility, and innovation using data-driven intelligence and advanced technologies.\n\nVision:\nTo emerge as a global technology partner of choice by continuously innovating, adapting, and integrating futuristic solutions that bridge the gap between technology and business outcomes.\n\nCore Values:'), Document(metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='Core Values:\n\nInnovation First: Constantly evolving to integrate emerging technologies into real-world business problems.\n\nIntegrity: Building trustworthy digital ecosystems with transparency and accountability.\n\nClient Centricity: Focusing on measurable business impact and long-term value for clients.\n\nCollaboration: Promoting teamwork across multi-disciplinary functions and partner ecosystems.\n\nExcellence: Commitment to quality, scalability, and performance across all engagements.\n\n3. Services & Technology Portfolio\n\nDatopic’s expertise covers a broad spectrum of digital transformation services, strategically grouped under five main service lines:\n\na) Product Engineering and Software Development\n\nDatopic specializes in end-to-end product lifecycle management, helping clients conceptualize, design, develop, test, and deploy software applications and digital platforms. The company focuses on agile and DevOps methodologies to ensure rapid delivery with high scalability and maintainability.\n\nTechnologies used include Python, Java, Node.js, React, TensorFlow, AWS, and Azure, among others. Solutions range from enterprise web applications to AI-integrated products and IoT dashboards.\n\nb) Artificial Intelligence and Data Analytics\n\nDatopic’s data division focuses on predictive analytics, natural language processing (NLP), and computer vision. It helps organizations harness raw data to gain actionable insights through machine learning models, data visualization, and intelligent automation.\n\nTypical use cases include:\n\nPredictive maintenance for manufacturing.\n\nFraud detection and anomaly identification for financial systems.\n\nAI chatbots and recommendation systems for customer engagement.\n\n ...

# %%
# embeddings
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

embedding = HuggingFaceEmbeddings(model="all-MiniLM-L6-v2")
# Out:
# c:\Users\pouru\Desktop\LangChain\venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\pouru\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`

# %%
# storing in vector stores (chroma)

vector_store = Chroma.from_documents(docs, embedding)

# %%
-vector_store.similarity_search("datopic")
# Out:
# [Document(id='6647de1e-f478-4815-b358-d273a1586887', metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='1. Company Overview\n\nDatopic Technologies Private Limited is an India-based emerging technology and innovation-driven IT services company, incorporated on 7 February 2017 under the Companies Act, 2013. Its Corporate Identification Number (CIN) is U74999DL2017PTC312445, and it is registered with the Registrar of Companies, Delhi.\n\nThe company’s registered office is located at RZ-77A, Dabri Extension, Main Palam Road, New Delhi – 110045, India. Operationally, Datopic has also established a significant presence in Noida, Uttar Pradesh, serving as its primary technology and development hub.\n\nDatopic Technologies is guided by the vision of “transforming data into intelligence and innovation into action.” Its central focus lies in building next-generation digital solutions for enterprises, leveraging cutting-edge technologies such as Artificial Intelligence (AI), Blockchain, Cloud Computing, Cybersecurity, and Data Analytics.\n\nWith a lean yet talented workforce (estimated 20–50 professionals), Datopic has rapidly built credibility through specialized digital transformation projects, catering to both domestic and international clients. The company aims to empower organizations to reimagine their operations, enhance decision-making, and achieve sustainable digital growth through the intelligent application of emerging technologies.\n\nKey leadership includes Mr. Saurabh Jain and Mr. Sumit Chauhan, both experienced technology professionals with deep expertise in enterprise systems, digital solutions, and IT consulting.\n\n2. Mission, Vision, and Core Values\n\nMission:\nTo deliver intelligent and secure digital transformation solutions that empower enterprises to maximize efficiency, agility, and innovation using data-driven intelligence and advanced technologies.\n\nVision:\nTo emerge as a global technology partner of choice by continuously innovating, adapting, and integrating futuristic solutions that bridge the gap between technology and business outcomes.\n\nCore Values:\n\nInnovation First: Constantly evolving to integrate emerging technologies into real-world business problems.\n\nIntegrity: Building trustworthy digital ecosystems with transparency and accountability.\n\nClient Centricity: Focusing on measurable business impact and long-term value for clients.\n\nCollaboration: Promoting teamwork across multi-disciplinary functions and partner ecosystems.\n\nExcellence: Commitment to quality, scalability, and performance across all engagements.\n\n3. Services & Technology Portfolio\n\nDatopic’s expertise covers a broad spectrum of digital transformation services, strategically grouped under five main service lines:\n\na) Product Engineering and Software Development\n\nDatopic specializes in end-to-end product lifecycle management, helping clients conceptualize, design, develop, test, and deploy software applications and digital platforms. The company focuses on agile and DevOps methodologies to ensure rapid delivery with high scalability and maintainability.\n\nTechnologies used include Python, Java, Node.js, React, TensorFlow, AWS, and Azure, among others. Solutions range from enterprise web applications to AI-integrated products and IoT dashboards.\n\nb) Artificial Intelligence and Data Analytics\n\nDatopic’s data division focuses on predictive analytics, natural language processing (NLP), and computer vision. It helps organizations harness raw data to gain actionable insights through machine learning models, data visualization, and intelligent automation.\n\nTypical use cases include:\n\nPredictive maintenance for manufacturing.\n\nFraud detection and anomaly identification for financial systems.\n\nAI chatbots and recommendation systems for customer engagement.\n\nc) Cybersecurity and Infrastructure Management\n\nIn today’s data-driven economy, Datopic off ...

# %%
# asyn query

await vector_store.asimilarity_search("datopic")
# Out:
# [Document(id='6647de1e-f478-4815-b358-d273a1586887', metadata={'source': 'C:\\Users\\pouru\\Desktop\\LangChain\\Lanchain_AgenticAI\\data\\text.txt'}, page_content='1. Company Overview\n\nDatopic Technologies Private Limited is an India-based emerging technology and innovation-driven IT services company, incorporated on 7 February 2017 under the Companies Act, 2013. Its Corporate Identification Number (CIN) is U74999DL2017PTC312445, and it is registered with the Registrar of Companies, Delhi.\n\nThe company’s registered office is located at RZ-77A, Dabri Extension, Main Palam Road, New Delhi – 110045, India. Operationally, Datopic has also established a significant presence in Noida, Uttar Pradesh, serving as its primary technology and development hub.\n\nDatopic Technologies is guided by the vision of “transforming data into intelligence and innovation into action.” Its central focus lies in building next-generation digital solutions for enterprises, leveraging cutting-edge technologies such as Artificial Intelligence (AI), Blockchain, Cloud Computing, Cybersecurity, and Data Analytics.\n\nWith a lean yet talented workforce (estimated 20–50 professionals), Datopic has rapidly built credibility through specialized digital transformation projects, catering to both domestic and international clients. The company aims to empower organizations to reimagine their operations, enhance decision-making, and achieve sustainable digital growth through the intelligent application of emerging technologies.\n\nKey leadership includes Mr. Saurabh Jain and Mr. Sumit Chauhan, both experienced technology professionals with deep expertise in enterprise systems, digital solutions, and IT consulting.\n\n2. Mission, Vision, and Core Values\n\nMission:\nTo deliver intelligent and secure digital transformation solutions that empower enterprises to maximize efficiency, agility, and innovation using data-driven intelligence and advanced technologies.\n\nVision:\nTo emerge as a global technology partner of choice by continuously innovating, adapting, and integrating futuristic solutions that bridge the gap between technology and business outcomes.\n\nCore Values:\n\nInnovation First: Constantly evolving to integrate emerging technologies into real-world business problems.\n\nIntegrity: Building trustworthy digital ecosystems with transparency and accountability.\n\nClient Centricity: Focusing on measurable business impact and long-term value for clients.\n\nCollaboration: Promoting teamwork across multi-disciplinary functions and partner ecosystems.\n\nExcellence: Commitment to quality, scalability, and performance across all engagements.\n\n3. Services & Technology Portfolio\n\nDatopic’s expertise covers a broad spectrum of digital transformation services, strategically grouped under five main service lines:\n\na) Product Engineering and Software Development\n\nDatopic specializes in end-to-end product lifecycle management, helping clients conceptualize, design, develop, test, and deploy software applications and digital platforms. The company focuses on agile and DevOps methodologies to ensure rapid delivery with high scalability and maintainability.\n\nTechnologies used include Python, Java, Node.js, React, TensorFlow, AWS, and Azure, among others. Solutions range from enterprise web applications to AI-integrated products and IoT dashboards.\n\nb) Artificial Intelligence and Data Analytics\n\nDatopic’s data division focuses on predictive analytics, natural language processing (NLP), and computer vision. It helps organizations harness raw data to gain actionable insights through machine learning models, data visualization, and intelligent automation.\n\nTypical use cases include:\n\nPredictive maintenance for manufacturing.\n\nFraud detection and anomaly identification for financial systems.\n\nAI chatbots and recommendation systems for customer engagement.\n\nc) Cybersecurity and Infrastructure Management\n\nIn today’s data-driven economy, Datopic off ...
